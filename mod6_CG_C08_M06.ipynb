# %% [markdown]
# ## Lab: Gaussian Mixture Models
#
# Motivation
#
# In this lab, you will apply Gaussian Mixture Models (GMM) to the Breast Cancer Wisconsin Diagnostic dataset. Unlike K-Means, GMM uses probabilistic clustering, allowing for soft assignments rather than strict cluster boundaries. This makes it useful for identifying uncertainty in clustering, such as anomalies in data.
#
# By completing the steps, you will:
#
# * Prepare and scale the dataset.
# * Determine the optimal number of clusters using BIC (Bayesian Information Criterion).
# * Perform clustering using GMM and evaluate its quality using Silhouette Score.
# * Identify potential anomalies based on cluster probabilities.
# * Compare GMM with K-Means clustering.
#
#
# This lab is auto-graded in CodeGrade, so follow the steps carefully.

# %% [markdown]
# ### Step 0: Load and Prepare the Dataset (Provided)
# The code for this step is already given. It performs the following:
#
# * Imports necessary libraries, including GaussianMixture from sklearn.mixture.
# * Loads the Breast Cancer dataset from sklearn.datasets.load_breast_cancer().
# * Creates a DataFrame with feature data.
# * Removes labels to simulate an unsupervised learning scenario.
#
# No modifications are needed for this step.

# %%
# CodeGrade step0

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.datasets import load_breast_cancer
# Out:
# c:\Users\marha\.conda\envs\ml\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# CodeGrade step0

# Load dataset
cancer = load_breast_cancer()
df = pd.DataFrame(cancer.data, columns=cancer.feature_names)

# Remove labels (unsupervised learning)
df_unlabeled = df.copy()

# %% [markdown]
# ### Step 1: Rescale the Data
# Objective: Standardize the dataset before applying GMM.
#
# Instructions
# * Use StandardScaler from sklearn.preprocessing to normalize all features.
# * Fit the scaler to the dataset and transform it into a new variable called df_scaled.
# * Ensure that df_scaled retains the same shape as the original data.

# %%
# CodeGrade step1

# Rescale
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_unlabeled)

# Shape
df_scaled.shape
# Out:
# (569, 30)

# %% [markdown]
# ### Step 2: Determine the Optimal Number of Components (BIC & AIC)
# Objective: Use Bayesian Information Criterion (BIC) and Akaike Information Criterion (AIC) to find the best number of clusters.
#
# Instructions
# * Initialize two empty lists: bic_scores and aic_scores.
# * Loop over values of K from 1 to 9:
#   * Train a GaussianMixture model with k components, random_state=42, and n_init=10.
#   * Fit the model to df_scaled and store the BIC and AIC scores.
# * Compute and return the difference between the sum of BIC scores and AIC scores, rounded to 0 decimal places.

# %%
# CodeGrade step2

# ic's for k
bic_scores = []
aic_scores = []
k_values = range(1, 9)

# for loop
for k in k_values:
    gmm = GaussianMixture(n_components=k, random_state=42, n_init=10)
    gmm.fit(df_scaled)
    bic_scores.append(gmm.bic(df_scaled))
    aic_scores.append(gmm.aic(df_scaled))

# Round sum of difference

# %% [markdown]
# Plot the BIC score to visualize the optimal K:
# * X-axis: Number of Components (K).
# * Y-axis: BIC Score.
# * Use markers ('o') and a line ('-').

# %%
# Plot BIC to find optimal K

plt.figure(figsize=(8, 5))
plt.plot(k_values, bic_scores, marker='o', linestyle='-', color='blue', label='BIC')
plt.plot(k_values, aic_scores, marker='o', linestyle='-', color='green', label='AIC')
plt.xlabel('Number of Components (K)')
plt.ylabel('Score')
plt.legend()
plt.title('BIC and AIC Scores for GMM')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Step 3: Perform GMM Clustering
# Objective: Apply GMM clustering using the best K from Step 2.
#
# Instructions
# * Set optimal_k  (determined from BIC analysis).
# * Train a GaussianMixture model with optimal_k, random_state=42, and n_init=10.
# * Assign cluster labels to df_unlabeled["GMM_Cluster"].
# * Compute and store maximum cluster probability for each sample in df_unlabeled["Cluster_Probability"].
# * Compute the Silhouette Score and return it rounded to 4 decimal places.

# %%
# CodeGrade step3

# Optimal k
optimal_k = 2
gmm = GaussianMixture(n_components=optimal_k, random_state=42, n_init=10)
# fit the model
gmm.fit(df_scaled)

# Assign probabilities to each cluster
df_unlabeled["GMM_Cluster"] = gmm.predict(df_scaled)
probs = gmm.predict_proba(df_scaled)
df_unlabeled["Cluster_Probability"] = np.max(probs, axis=1)

# Find and round the Silhouette Average
silhouette_avg = silhouette_score(df_scaled, df_unlabeled["GMM_Cluster"])

# round
round(silhouette_avg, 4)
# Out:
# 0.3145

# %% [markdown]
# ### Step 4: Identify Anomalies
# Objective: Detect outliers using cluster probability scores.
#
# Instructions
# * Compute the 5th percentile of df_unlabeled["Cluster_Probability"].
# * Define anomalies as all data points below this threshold.
# * Return the number of anomalies detected.

# %%
# CodeGrade step4

# Anomalies
min_prob = np.min(probs, axis=1)
threshold = np.percentile(min_prob, 5)
anomalies = df_unlabeled[min_prob < threshold]

# Number of anomalies
len(anomalies)
# Out:
# 29

# %%
threshold
# Out:
# 1.284300241410316e-309

# %%
anomalies
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 13         15.85         23.95          103.70      782.7          0.08401
# 41         10.95         21.35           71.90      371.1          0.12270
# 73         13.80         15.79           90.43      584.1          0.10070
# 100        13.61         24.98           88.05      582.7          0.09488
# 126        13.61         24.69           87.76      572.6          0.09258
# 147        14.95         18.77           97.84      689.5          0.08138
# 154        13.15         15.34           85.31      538.9          0.09384
# 157        16.84         19.46          108.40      880.2          0.07445
# 215        13.86         16.93           90.96      578.9          0.10260
# 227        15.00         15.51           97.45      684.5          0.08371
# 228        12.62         23.97           81.35      496.4          0.07903
# 255        13.96         17.05           91.43      602.4          0.10960
# 291        14.96         19.10           97.03      687.3          0.08992
# 330        16.03         15.51          105.80      793.2          0.09491
# 347        14.76         14.74           94.87      668.7          0.08875
# 363        16.50         18.29          106.60      838.1          0.09686
# 375        16.17         16.07          106.30      788.5          0.09880
# 388        11.27         15.50           73.38      392.0          0.08365
# 407        12.85         21.37           82.63      514.5          0.07551
# 413        14.99         22.11           97.53      693.7          0.08515
# 434        14.86         16.94           94.89      673.7          0.08924
# 435        13.98         19.62           91.12      599.5          0.10600
# 440        10.97         17.20           71.73      371.5          0.08915
# 466        13.14         20.74           85.98      536.9          0.08675
# 484        15.73         11.28          102.80      747.2          0.10430
# 508        16.30         15.70          104.70      819.8          0.09427
# 514        15.05         19.07           97.26      701.9          0.09215
# 536        14.27         22.55           93.77      629.8          0.10380
# 566        16.60         28.08          108.30      858.1          0.08455
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 13            0.10020         0.09938              0.05364         0.1847
# 41            0.12180         0.10440              0.05669         0.1895
# 73            0.12800         0.07789              0.05069         0.1662
# 100           0.08511         0.08625              0.04489         0.1609
# 126           0.07862         0.05285              0.03085         0.1761
# 147           0.11670         0.09050              0.03562         0.1744
# 154           0.08498         0.09293              0.03483         0.1822
# 157           0.07223         0.05150              0.02771         0.1844
# 215           0.15170         0.09901              0.05602         0.2106
# 227           0.10960         0.06505              0.03780         0.1881
# 228           0.07529         0.05438              0.02036         0.1514
# 255           0.12790         0.09789              0.05246         0.1908
# 291           0.09823         0.05940              0.04819         0.1879
# 330           0.13710         0.12040              0.07041         0.1782
# 347           0.07780         0.04608              0.03528         0.1521
# 363           0.08468         0.05862              0.04835         0.1495
# 375           0.14380         0.06651              0.05397         0.1990
# 388           0.11140         0.10070              0.02757         0.1810
# 407           0.08316         0.06126              0.01867         0.1580
# 413           0.10250         0.06859              0.03876         0.1944
# 434           0.07074         0.03346              0.02877         0.1573
# 435           0.11330         0.11260              0.06463         0.1669
# 440           0.11130         0.09457              0.03613         0.1489
# 466           0.10890         0.10850              0.03510         0.1562
# 484           0.12990         0.11910              0.06211         0.1784
# 508           0.06712         0.05526              0.04563         0.1711
# 514           0.08597         0.07486              0.04335         0.1561
# 536           0.11540         0.14630              0.06139         0.1926
# 566           0.10230         0.09251              0.05302         0.1590
#
#      mean fractal dimension  ...  worst perimeter  worst area  \
# 13                  0.05338  ...           112.00       876.5
# 41                  0.06870  ...            87.22       514.0
# 73                  0.06566  ...           110.30       812.4
# 100                 0.05871  ...           108.60       906.5
# 126                 0.06130  ...           113.20       848.7
# 147                 0.06493  ...           107.10       809.7
# 154                 0.06207  ...            97.67       677.3
# 157                 0.05268  ...           120.30      1032.0
# 215                 0.06916  ...           104.40       750.1
# 227                 0.05907  ...           114.20       808.2
# 228                 0.06019  ...            90.67       624.0
# 255                 0.06130  ...           108.10       826.0
# 291                 0.05852  ...           109.10       809.8
# 330                 0.05976  ...           124.30      1070.0
# 347                 0.05912  ...           114.20       880.8
# 363                 0.05593  ...           117.20      1009.0
# 375                 0.06572  ...           113.10       861.5
# 388                 0.07252  ...            79.73       450.0
# 407                 0.06114  ...            91.63       645.8
# 413                 0.05913  ...           110.20       867.1
# 434                 0.05703  ...           102.30       777.5
# 435                 0.06544  ...           113.90       869.3
# 440                 0.06640  ...            90.14       476.4
# 466                 0.06020  ...           100.90       689.1
# 484                 0.06259  ...           112.50       854.3
# 508                 0.05657  ...           109.80       928.2
# 514                 0.05915  ...           113.80       967.0
# 536                 0.05982  ...           104.30       728.3
# 566                 0.05648  ...           126.70      1124.0
#
#      worst smoothness  worst compactness  worst concavity  \
# 13            0.11310             0.1924           0.2322
# 41            0.19090             0.2698           0.4023
# 73            0.14110             0.3542           0.2779
# 100           0.12650             0.1943           0.3169
# 126           0.14710             0.2884           0.3796
# 147           0.09970             0.2521           0.2500
# 154           0.14780             0.2256           0.3009
# 157           0.08774             0.1710           0.1882
# 215           0.14600             0.4370           0.4636
# 227           0.11360             0.3627           0.3402
# 228           0.12270             0.3454           0.3911
# 255           0.15120             0.3262           0.3209
# 291           0.13130             0.3030           0.1804
# 330           0.14350             0.4478           0.4956
# 347           0.12200             0.2009           0.2151
# 363           0.13380             0.1679           0.1663
# 375           0.12350             0.2550           0.2114
# 388           0.11020             0.2809           0.3021
# 407           0.09402             0.1936           0.1838
# 413           0.10770             0.3345           0.3114
# 434           0.12180             0.1550           0.1220
# 435           0.16130             0.3568           0.4069
# 440           0.13910             0.4082           0.4779
# 466           0.13510             0.3549           0.4504
# 484           0.15410             0.2979           0.4004
# 508           0.13540             0.1361           0.1947
# 514           0.12460             0.2101           0.2866
# 536           0.13800             0.2733           0.4234
# 566           0.11390             0.3094           0.3403
#
#      worst concave points  worst symmetry  worst fractal dimension  \
# 13                0.11190          0.2809                  0.06287
# 41                0.14240          0.2964                  0.09606
# 73                0.13830          0.2589                  0.10300
# 100               0.11840          0.2651                  0.07397
# 126               0.13290          0.3470                  0.07900
# 147               0.08405          0.2852                  0.09218
# 154               0.09722          0.3849                  0.08633
# 157               0.08436          0.2527                  0.05972
# 215               0.16540          0.3630                  0.10590
# 227               0.13790          0.2954                  0.08362
# 228               0.11800          0.2826                  0.09585
# 255               0.13740          0.3068                  0.07957
# 291               0.14890          0.2962                  0.08472
# 330               0.19810          0.3019                  0.09124
# 347               0.12510          0.3109                  0.08187
# 363               0.09123          0.2394                  0.06469
# 375               0.12510          0.3153                  0.08960
# 388               0.08272          0.2157                  0.10430
# 407               0.05601          0.2488                  0.08151
# 413               0.13080          0.3163                  0.09251
# 434               0.07971          0.2525                  0.06827
# 435               0.18270          0.3179                  0.10550
# 440               0.15550          0.2540                  0.09532
# 466               0.11810          0.2563                  0.08174
# 484               0.14520          0.2557                  0.08181
# 508               0.13570          0.2300                  0.07230
# 514               0.11200          0.2282                  0.06954
# 536               0.13620          0.2698                  0.08351
# 566               0.14180          0.2218                  0.07820
#
#      GMM_Cluster  Cluster_Probability
# 13             1             0.975104
# 41             1             0.999854
# 73             1             0.999031
# 100            0             0.998094
# 126            0             0.999223
# 147            0             0.998876
# 154            1             0.999188
# 157            1             0.995466
# 215            1             0.999677
# 227            1             0.999130
# 228            1             0.999481
# 255            1             0.999946
# 291            1             0.913224
# 330            0             0.999842
# 347            1             0.998976
# 363            1             0.999689
# 375            1             0.998772
# 388            1             0.986272
# 407            1             0.997830
# 413            1             0.999928
# 434            1             0.999682
# 435            0             0.987530
# 440            1             0.968014
# 466            1             0.999010
# 484            1             0.999807
# 508            1             0.993874
# 514            1             0.969389
# 536            0             0.997778
# 566            0             0.999812
#
# [29 rows x 32 columns]

# %% [markdown]
# ### Step 5: Compare GMM with K-Means
# Objective: Compare cluster assignments and visualize results.
#
# Instructions
# * Train a K-Means model using the same optimal_k = 2 as GMM.
# * Assign cluster labels to df_unlabeled["KMeans_Cluster"].
# * Create a crosstab of GMM and K-Means cluster assignments and return its shape.
# * Apply PCA (n_components=2) to reduce dimensions.

# %%
# CodeGrade step5

# Clusering with K-means
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df_unlabeled["KMeans_Cluster"] = kmeans.fit_predict(df_scaled)

# Compare clustering assignments
comparison = pd.crosstab(df_unlabeled['GMM_Cluster'], df_unlabeled['KMeans_Cluster']) # use cross.tab()

# Return the shape of the value counts
comparison.value_counts().shape
# Out:
# (2,)

# %% [markdown]
# * Plot GMM clustering results in 2D:
#   * X-axis: Principal Component 1.
#   * Y-axis: Principal Component 2.
#   * Color points by GMM Cluster.
#   * Use cmap='viridis', marker 'o', and edgecolor='k'.
# * Create another plot overlaying anomalies:
#   * Mark anomalies with red 'x' symbols.

# %%
# pca
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled)

# plot gmm
plt.figure(figsize=(8, 5))
plt.scatter(df_pca[:, 0], df_pca[:, 1], c=df_unlabeled["GMM_Cluster"], cmap='viridis', marker='o', edgecolor='k')
plt.xlabel("Feature 1 (Standardized)")
plt.ylabel("Feature 2 (Standardized)")
plt.title("GMM Clustering Results on Cancer Data (PCA Reduced)")
plt.colorbar(label="Cluster")
plt.show()

# %%
# plot gmm with anomalies
plt.scatter(df_scaled[:, 0], df_scaled[:, 1], c=df_unlabeled["GMM_Cluster"], cmap='viridis', alpha=0.6, label="Clusters")

# Highlight anomalies
plt.scatter(anomalies['Cluster_Probability'], color='red', marker='x', s=100, label="Anomalies")

# Plot cluster centers
plt.scatter(gmm.means_[:, 0], gmm.means_[:, 1], s=200, c='black', marker='X', label="Cluster Centers")

plt.title('GMM Clustering and Anomaly Detection')
plt.xlabel('Feature 1 (Standardized)')
plt.ylabel('Feature 2 (Standardized)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 5
#       2 plt.scatter(df_scaled[:, 0], df_scaled[:, 1], c=df_unlabeled["GMM_Cluster"], cmap='viridis', alpha=0.6, label="Clusters")
#       4 # Highlight anomalies
# ----> 5 plt.scatter(anomalies['Cluster_Probability'], color='red', marker='x', s=100, label="Anomalies")
#       7 # Plot cluster centers
#       8 plt.scatter(gmm.means_[:, 0], gmm.means_[:, 1], s=200, c='black', marker='X', label="Cluster Centers")
#
# TypeError: scatter() missing 1 required positional argument: 'y'
