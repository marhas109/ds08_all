# %% [markdown]
# Clustering is an essential technique in unsupervised machine learning, where the goal is to group data points based on similarities without predefined labels.
#
# In this lesson, we will apply K-Means clustering to the Iris dataset, a widely used dataset in machine learning. The objective is to segment the dataset into meaningful clusters and evaluate how well K-Means performs in identifying the natural groupings within the data.

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Set the random seed for reproducibility
np.random.seed(42)

# Load the Iris dataset
iris = sns.load_dataset('iris')
iris_data = iris.drop(columns=['species'])

iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# standardize the data
scaler = StandardScaler()
scaled_iris = scaler.fit_transform(iris_data)

# %%
# Find optimal clusters using the Elbow Method
wcss = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_iris)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Curve

plt.figure(figsize=(8, 5))
plt.plot(range(1, 10), wcss, marker='o', linestyle='-')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("WCSS")
plt.title("Elbow Method for Optimal K")
plt.show()

# %%
# Apply K-Means with the optimal K (from above)
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
iris_data['Cluster'] = kmeans.fit_predict(scaled_iris)

# %%
# Validate clustering with Silhouette Score
silhouette_avg = silhouette_score(scaled_iris, iris_data['Cluster'])
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.45994823920518646

# %%
# PCA to visualize
pca = PCA(n_components=2)
iris_pca = pca.fit_transform(scaled_iris)

# Scatterplot of clusters

plt.figure(figsize=(8, 5))
plt.scatter(iris_pca[:, 0], iris_pca[:, 1], c=iris_data["Cluster"], cmap='viridis', marker='o', edgecolor='k')
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("K-Means Clustering Results on Iris (PCA Reduced)")
plt.colorbar(label="Cluster")
plt.show()

# %%
# Analyze the cluster properties
cluster_means = iris_data.groupby('Cluster').mean()
print(cluster_means)
# Out:
#          sepal_length  sepal_width  petal_length  petal_width
# Cluster
# 0            5.801887     2.673585      4.369811     1.413208
# 1            5.006000     3.428000      1.462000     0.246000
# 2            6.780851     3.095745      5.510638     1.972340

# %%
# Compare results to actual species labels
iris["Predicted_Cluster"] = iris_data["Cluster"]
print(iris.groupby(["species", "Predicted_Cluster"]).size())
# Out:
# species     Predicted_Cluster
# setosa      1                    50
# versicolor  0                    39
#             2                    11
# virginica   0                    14
#             2                    36
# dtype: int64
